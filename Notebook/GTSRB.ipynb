# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Load Data

# %%
train_data = pd.read_csv('Train.csv')
test_data = pd.read_csv('Test.csv')
meta_data = pd.read_csv('Meta.csv')

# %%
train_data.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path
# 0  Train/20/00020_00000_00000.png
# 1  Train/20/00020_00000_00001.png
# 2  Train/20/00020_00000_00002.png
# 3  Train/20/00020_00000_00003.png
# 4  Train/20/00020_00000_00004.png

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39209 entries, 0 to 39208
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Width    39209 non-null  int64
#  1   Height   39209 non-null  int64
#  2   Roi.X1   39209 non-null  int64
#  3   Roi.Y1   39209 non-null  int64
#  4   Roi.X2   39209 non-null  int64
#  5   Roi.Y2   39209 non-null  int64
#  6   ClassId  39209 non-null  int64
#  7   Path     39209 non-null  str
# dtypes: int64(7), str(1)
# memory usage: 2.4 MB

# %%
test_data.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
meta_data.head()
# Out:
#           Path  ClassId  ShapeId  ColorId SignId
# 0  Meta/27.png       27        0        0   1.32
# 1   Meta/0.png        0        1        0   3.29
# 2   Meta/1.png        1        1        0   3.29
# 3  Meta/10.png       10        1        0   3.27
# 4  Meta/11.png       11        0        0   1.22

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))

# 1️⃣ Width Distribution
sns.histplot(train_data["Width"], bins=40, kde=True, ax=ax[0])
ax[0].set_title("Width Distribution")
ax[0].set_xlabel("Width")

# 2️⃣ Height Distribution
sns.histplot(train_data["Height"], bins=40, kde=True, ax=ax[1])
ax[1].set_title("Height Distribution")
ax[1].set_xlabel("Height")

# 3️⃣ Class Distribution
sns.countplot(
    data=train_data,
    x='ClassId',
    order=train_data['ClassId'].value_counts().index,
    ax=ax[2]
)
ax[2].set_title("Class Distribution - Train Set")
ax[2].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))

sample_data = train_data.sample(3000, random_state=42)

sns.regplot(
    data=sample_data,
    x='Width',
    y='Height',
    scatter_kws={'alpha':0.4},
    line_kws={'color':'red'}
)

plt.title('Width vs Height Distribution with Trend Line')
plt.show()

# %%
plt.figure(figsize=(8,6))

numeric_cols = ['Width','Height','Roi.X1','Roi.Y1','Roi.X2','Roi.Y2']

corr = train_data[numeric_cols].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title("Feature Correlation")
plt.show()

# %% [markdown]
# # Load Train - Test

# %%
import cv2
import os

# Load Images Function
IMG_SIZE = 64

def load_images(df):

    images = []
    labels = []

    for _, row in df.iterrows():

        img_path = row['Path']

        img = cv2.imread(img_path)

        if img is None:
            continue

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))

        images.append(img)
        labels.append(row['ClassId'])

    return np.array(images), np.array(labels)

# %%
X_train, y_train = load_images(train_data)
X_test, y_test = load_images(test_data)

print(X_train.shape)
print(X_test.shape)
# Out:
# (39209, 64, 64, 3)
# (12630, 64, 64, 3)

# %% [markdown]
# # Train Validation Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    stratify=y_train,
    random_state=42
)

# %% [markdown]
# # Load Dataset Properly

# %%
import tensorflow as tf
from keras import layers, models
from keras.utils import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Convert to TensorFlow Dataset
BATCH_SIZE = 16

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds = val_ds.batch(BATCH_SIZE)

test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_ds = test_ds.batch(BATCH_SIZE)

# %% [markdown]
# # Data Augmentation Layer

# %%
data_augmentation = tf.keras.Sequential([

    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.05, 0.05)
])

# %% [markdown]
# # Modelling

# %%
#CNN Model
def build_cnn_model(input_shape=(64,64,3), num_classes=43):

    model = tf.keras.Sequential([

        layers.Input(shape=input_shape),

        data_augmentation,

        layers.Rescaling(1./255),

        layers.Conv2D(32,3,activation='relu'),
        layers.MaxPooling2D(),

        layers.Conv2D(64,3,activation='relu'),
        layers.MaxPooling2D(),

        layers.Conv2D(128,3,activation='relu'),
        layers.MaxPooling2D(),

        layers.Conv2D(256,3,activation='relu'),
        layers.MaxPooling2D(),

        layers.Flatten(),
        layers.Dense(256,activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes,activation='softmax')

    ])

    return model

# %%
from keras.applications import MobileNetV2
from keras.applications.mobilenet_v2 import preprocess_input

def build_mobilenet_model(input_shape=(64, 64, 3), num_classes=43):

    base_model = MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )

    base_model.trainable = False

    inputs = tf.keras.Input(shape=input_shape)

    # augmentation
    x = data_augmentation(inputs)

    # preprocess mobilenet
    x = preprocess_input(x)

    # feature extractor
    x = base_model(x, training=False)

    # classifier head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)

    return model

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Training Function
def train_model(model, train_ds, val_ds, epochs=30):

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.3,
        patience=3
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[early_stop, reduce_lr]
    )

    return history

# %%
# Training Models

models = {
    'CNN': build_cnn_model(),
    'MobileNetV2': build_mobilenet_model()
}

histories = {}
results = {}

for name, model in models.items():
    print(f"\nTraining {name}")
    history = train_model(model, train_ds, val_ds)
    test_loss, test_acc = model.evaluate(test_ds)

    histories[name] = history
    results[name] = {
        'Test Loss': test_loss,
        'Test Accuracy': test_acc
    }

print('\n------- Model Result -------')

for name, metrics in results.items():
    print(f"\n{name}")
    print(f"Test Loss : {metrics['Test Loss']:.4f}")
    print(f"Test Accuracy : {metrics['Test Accuracy']:.4f}")
# Out:
# C:\Users\AtikahDR\AppData\Local\Temp\ipykernel_10060\2041056874.py:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Training CNN
# Epoch 1/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 434s 218ms/step - accuracy: 0.5068 - loss: 1.6434 - val_accuracy: 0.9149 - val_loss: 0.2649 - learning_rate: 0.0010
# Epoch 2/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 431s 220ms/step - accuracy: 0.8830 - loss: 0.3638 - val_accuracy: 0.9733 - val_loss: 0.0892 - learning_rate: 0.0010
# Epoch 3/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 435s 222ms/step - accuracy: 0.9443 - loss: 0.1805 - val_accuracy: 0.9899 - val_loss: 0.0336 - learning_rate: 0.0010
# Epoch 4/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 437s 223ms/step - accuracy: 0.9598 - loss: 0.1289 - val_accuracy: 0.9890 - val_loss: 0.0357 - learning_rate: 0.0010
# Epoch 5/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 435s 222ms/step - accuracy: 0.9694 - loss: 0.1038 - val_accuracy: 0.9916 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 6/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 430s 219ms/step - accuracy: 0.9727 - loss: 0.0930 - val_accuracy: 0.9941 - val_loss: 0.0173 - learning_rate: 0.0010
# Epoch 7/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 430s 219ms/step - accuracy: 0.9762 - loss: 0.0798 - val_accuracy: 0.9958 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 8/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 433s 221ms/step - accuracy: 0.9792 - loss: 0.0696 - val_accuracy: 0.9934 - val_loss: 0.0202 - learning_rate: 0.0010
# Epoch 9/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 433s 221ms/step - accuracy: 0.9808 - loss: 0.0674 - val_accuracy: 0.9921 - val_loss: 0.0264 - learning_rate: 0.0010
# Epoch 10/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 432s 220ms/step - accuracy: 0.9811 - loss: 0.0697 - val_accuracy: 0.9927 - val_loss: 0.0261 - learning_rate: 0.0010
# Epoch 11/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 431s 220ms/step - accuracy: 0.9909 - loss: 0.0306 - val_accuracy: 0.9982 - val_loss: 0.0069 - learning_rate: 3.0000e-04
# Epoch 12/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 435s 222ms/step - accuracy: 0.9942 - loss: 0.0198 - val_accuracy: 0.9973 - val_loss: 0.0103 - learning_rate: 3.0000e-04
# Epoch 13/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 436s 222ms/step - accuracy: 0.9942 - loss: 0.0202 - val_accuracy: 0.9976 - val_loss: 0.0118 - learning_rate: 3.0000e-04
# Epoch 14/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 436s 222ms/step - accuracy: 0.9947 - loss: 0.0188 - val_accuracy: 0.9985 - val_loss: 0.0068 - learning_rate: 3.0000e-04
# Epoch 15/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 438s 223ms/step - accuracy: 0.9971 - loss: 0.0098 - val_accuracy: 0.9985 - val_loss: 0.0066 - learning_rate: 9.0000e-05
# Epoch 16/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 435s 222ms/step - accuracy: 0.9971 - loss: 0.0090 - val_accuracy: 0.9986 - val_loss: 0.0079 - learning_rate: 9.0000e-05
# Epoch 17/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 437s 223ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9987 - val_loss: 0.0060 - learning_rate: 9.0000e-05
# Epoch 18/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 435s 222ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.9991 - val_loss: 0.0048 - learning_rate: 9.0000e-05
# Epoch 19/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 438s 224ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9989 - val_loss: 0.0049 - learning_rate: 9.0000e-05
# Epoch 20/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 436s 222ms/step - accuracy: 0.9978 - loss: 0.0093 - val_accuracy: 0.9990 - val_loss: 0.0054 - learning_rate: 9.0000e-05
# Epoch 21/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 436s 222ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9991 - val_loss: 0.0042 - learning_rate: 9.0000e-05
# Epoch 22/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 437s 223ms/step - accuracy: 0.9984 - loss: 0.0059 - val_accuracy: 0.9990 - val_loss: 0.0054 - learning_rate: 9.0000e-05
# Epoch 23/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 437s 223ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9987 - val_loss: 0.0074 - learning_rate: 9.0000e-05
# Epoch 24/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 438s 223ms/step - accuracy: 0.9983 - loss: 0.0065 - val_accuracy: 0.9987 - val_loss: 0.0070 - learning_rate: 9.0000e-05
# Epoch 25/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 438s 223ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9989 - val_loss: 0.0048 - learning_rate: 2.7000e-05
# Epoch 26/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 449s 229ms/step - accuracy: 0.9981 - loss: 0.0065 - val_accuracy: 0.9990 - val_loss: 0.0048 - learning_rate: 2.7000e-05
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 65s 82ms/step - accuracy: 0.9856 - loss: 0.0935
#
# Training MobileNetV2
# Epoch 1/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 269s 102ms/step - accuracy: 0.4676 - loss: 1.8131 - val_accuracy: 0.6521 - val_loss: 1.0740 - learning_rate: 0.0010
# Epoch 2/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 193s 98ms/step - accuracy: 0.5668 - loss: 1.3455 - val_accuracy: 0.6771 - val_loss: 1.0011 - learning_rate: 0.0010
# Epoch 3/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.5944 - loss: 1.2473 - val_accuracy: 0.7063 - val_loss: 0.9242 - learning_rate: 0.0010
# Epoch 4/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 187s 96ms/step - accuracy: 0.6086 - loss: 1.2014 - val_accuracy: 0.7197 - val_loss: 0.8864 - learning_rate: 0.0010
# Epoch 5/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6212 - loss: 1.1536 - val_accuracy: 0.7326 - val_loss: 0.8366 - learning_rate: 0.0010
# Epoch 6/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6330 - loss: 1.1241 - val_accuracy: 0.7436 - val_loss: 0.8373 - learning_rate: 0.0010
# Epoch 7/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.6408 - loss: 1.0994 - val_accuracy: 0.7476 - val_loss: 0.8253 - learning_rate: 0.0010
# Epoch 8/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 187s 96ms/step - accuracy: 0.6455 - loss: 1.0770 - val_accuracy: 0.7512 - val_loss: 0.8211 - learning_rate: 0.0010
# Epoch 9/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6587 - loss: 1.0547 - val_accuracy: 0.7492 - val_loss: 0.8415 - learning_rate: 0.0010
# Epoch 10/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.6600 - loss: 1.0453 - val_accuracy: 0.7575 - val_loss: 0.8201 - learning_rate: 0.0010
# Epoch 11/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6608 - loss: 1.0403 - val_accuracy: 0.7613 - val_loss: 0.8142 - learning_rate: 0.0010
# Epoch 12/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6719 - loss: 1.0083 - val_accuracy: 0.7725 - val_loss: 0.7673 - learning_rate: 0.0010
# Epoch 13/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6719 - loss: 1.0071 - val_accuracy: 0.7734 - val_loss: 0.7659 - learning_rate: 0.0010
# Epoch 14/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6794 - loss: 0.9827 - val_accuracy: 0.7760 - val_loss: 0.7665 - learning_rate: 0.0010
# Epoch 15/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 192s 98ms/step - accuracy: 0.6820 - loss: 0.9817 - val_accuracy: 0.7827 - val_loss: 0.7507 - learning_rate: 0.0010
# Epoch 16/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.6839 - loss: 0.9726 - val_accuracy: 0.7841 - val_loss: 0.7489 - learning_rate: 0.0010
# Epoch 17/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6851 - loss: 0.9651 - val_accuracy: 0.7799 - val_loss: 0.7572 - learning_rate: 0.0010
# Epoch 18/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.6919 - loss: 0.9597 - val_accuracy: 0.7840 - val_loss: 0.7612 - learning_rate: 0.0010
# Epoch 19/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.6913 - loss: 0.9477 - val_accuracy: 0.7827 - val_loss: 0.7624 - learning_rate: 0.0010
# Epoch 20/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.7153 - loss: 0.8746 - val_accuracy: 0.8007 - val_loss: 0.7010 - learning_rate: 3.0000e-04
# Epoch 21/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.7273 - loss: 0.8317 - val_accuracy: 0.8012 - val_loss: 0.6965 - learning_rate: 3.0000e-04
# Epoch 22/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.7315 - loss: 0.8156 - val_accuracy: 0.8118 - val_loss: 0.6610 - learning_rate: 3.0000e-04
# Epoch 23/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.7350 - loss: 0.8061 - val_accuracy: 0.8134 - val_loss: 0.6719 - learning_rate: 3.0000e-04
# Epoch 24/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.7408 - loss: 0.7916 - val_accuracy: 0.8170 - val_loss: 0.6496 - learning_rate: 3.0000e-04
# Epoch 25/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.7445 - loss: 0.7766 - val_accuracy: 0.8168 - val_loss: 0.6432 - learning_rate: 3.0000e-04
# Epoch 26/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 189s 96ms/step - accuracy: 0.7423 - loss: 0.7798 - val_accuracy: 0.8217 - val_loss: 0.6406 - learning_rate: 3.0000e-04
# Epoch 27/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 188s 96ms/step - accuracy: 0.7494 - loss: 0.7642 - val_accuracy: 0.8234 - val_loss: 0.6434 - learning_rate: 3.0000e-04
# Epoch 28/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 197s 100ms/step - accuracy: 0.7482 - loss: 0.7572 - val_accuracy: 0.8213 - val_loss: 0.6179 - learning_rate: 3.0000e-04
# Epoch 29/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 198s 101ms/step - accuracy: 0.7495 - loss: 0.7543 - val_accuracy: 0.8234 - val_loss: 0.6242 - learning_rate: 3.0000e-04
# Epoch 30/30
# 1961/1961 ━━━━━━━━━━━━━━━━━━━━ 197s 100ms/step - accuracy: 0.7556 - loss: 0.7385 - val_accuracy: 0.8256 - val_loss: 0.6344 - learning_rate: 3.0000e-04
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.5692 - loss: 2.1637
#
# ------- Model Result -------
#
# CNN
# Test Loss : 0.0935
# Test Accuracy : 0.9856
#
# MobileNetV2
# Test Loss : 2.1637
# Test Accuracy : 0.5692

# %% [markdown]
# # Confusion Matrix

# %%
y_true = np.concatenate([y for x, y in test_ds], axis=0)

for name, model in models.items():

    print(f"---- {name} ----")

    # prediction
    y_pred_prob = model.predict(test_ds)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # classification report
    print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# ---- CNN ----
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       0.99      1.00      0.99       720
#            2       0.99      1.00      1.00       750
#            3       1.00      0.97      0.98       450
#            4       1.00      0.98      0.99       660
#            5       0.98      0.99      0.99       630
#            6       1.00      0.99      0.99       150
#            7       1.00      1.00      1.00       450
#            8       0.99      1.00      1.00       450
#            9       1.00      1.00      1.00       480
#           10       1.00      1.00      1.00       660
#           11       0.99      0.99      0.99       420
#           12       1.00      0.97      0.98       690
#           13       0.99      1.00      1.00       720
#           14       1.00      1.00      1.00       270
#           15       0.92      1.00      0.96       210
#           16       0.99      1.00      1.00       150
#           17       1.00      0.98      0.99       360
#           18       0.99      0.94      0.97       390
#           19       1.00      1.00      1.00        60
#           20       0.84      1.00      0.91        90
#           21       0.93      0.99      0.96        90
#           22       0.99      0.88      0.93       120
#           23       0.96      0.99      0.97       150
#           24       0.99      0.98      0.98        90
#           25       0.97      1.00      0.98       480
#           26       0.98      0.98      0.98       180
#           27       0.97      0.50      0.66        60
#           28       0.88      0.97      0.92       150
#           29       0.78      1.00      0.88        90
#           30       0.98      0.83      0.90       150
#           31       0.99      1.00      0.99       270
#           32       1.00      1.00      1.00        60
#           33       1.00      1.00      1.00       210
#           34       0.99      1.00      1.00       120
#           35       0.99      1.00      1.00       390
#           36       1.00      1.00      1.00       120
#           37       1.00      1.00      1.00        60
#           38       1.00      1.00      1.00       690
#           39       0.98      1.00      0.99        90
#           40       0.97      0.99      0.98        90
#           41       1.00      0.98      0.99        60
#           42       0.99      1.00      0.99        90
#
#     accuracy                           0.99     12630
#    macro avg       0.98      0.97      0.97     12630
# weighted avg       0.99      0.99      0.99     12630
#
# ---- MobileNetV2 ----
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step
#               precision    recall  f1-score   support
#
#            0       0.15      0.07      0.09        60
#            1       0.56      0.52      0.54       720
#            2       0.40      0.48      0.44       750
#            3       0.30      0.23      0.26       450
#            4       0.53      0.56      0.54       660
#            5       0.53      0.51      0.52       630
#            6       0.85      0.73      0.79       150
#            7       0.50      0.49      0.49       450
#            8       0.40      0.33      0.36       450
#            9       0.71      0.78      0.75       480
#           10       0.68      0.79      0.73       660
#           11       0.40      0.48      0.44       420
#           12       0.91      0.94      0.92       690
#           13       0.91      0.94      0.92       720
#           14       0.97      0.86      0.91       270
#           15       0.99      0.92      0.96       210
#           16       0.81      0.78      0.80       150
#           17       0.93      0.93      0.93       360
#           18       0.47      0.58      0.52       390
#           19       0.23      0.18      0.20        60
#           20       0.08      0.08      0.08        90
#           21       0.17      0.11      0.13        90
#           22       0.23      0.12      0.16       120
#           23       0.19      0.17      0.18       150
#           24       0.12      0.06      0.08        90
#           25       0.32      0.46      0.38       480
#           26       0.44      0.44      0.44       180
#           27       0.07      0.03      0.05        60
#           28       0.10      0.03      0.05       150
#           29       0.17      0.09      0.12        90
#           30       0.45      0.12      0.19       150
#           31       0.67      0.76      0.71       270
#           32       0.83      0.87      0.85        60
#           33       0.23      0.12      0.16       210
#           34       0.38      0.12      0.19       120
#           35       0.41      0.55      0.47       390
#           36       0.33      0.23      0.27       120
#           37       0.17      0.13      0.15        60
#           38       0.63      0.79      0.70       690
#           39       0.54      0.48      0.51        90
#           40       0.59      0.49      0.54        90
#           41       0.54      0.52      0.53        60
#           42       0.49      0.39      0.43        90
#
#     accuracy                           0.57     12630
#    macro avg       0.48      0.45      0.45     12630
# weighted avg       0.55      0.57      0.56     12630

# %%
# Confusion Matrix
for name, model in models.items():
    y_pred = model.predict(test_ds)
    y_pred = np.argmax(y_pred, axis=1)
    y_true = np.concatenate([y for x,y in test_ds], axis=0)

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10,8))
    sns.heatmap(cm, cmap='Blues')
    plt.title(f'Confusion Matrix {name}')
    plt.show()
# Out:
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 70s 88ms/step
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 57s 69ms/step

# %%
train_generator.class_indices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 train_generator.class_indices
#
# NameError: name 'train_generator' is not defined

# %%
# Learning Curve
plt.figure(figsize=(10,6))

for name, history in histories.items():
    plt.plot(history.history['val_accuracy'], label=name)

plt.legend()
plt.title("Model Comparison")
plt.show()

# %%
#Accuracy Comparison Graph
plt.figure(figsize=(10,6))

for name, history in histories.items():
    plt.plot(history.history['val_accuracy'], label=f'{name} Val Accuracy')
    plt.plot(history.history['accuracy'], linestyle='--', label=f'{name} Train Accuracy')

plt.title('CNN vs MobileNetV2 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Loss Comparison Graph
plt.figure(figsize=(10,6))

for name, history in histories.items():
    plt.plot(history.history['val_loss'], label=f'{name} Val Loss')
    plt.plot(history.history['loss'], linestyle='--', label=f'{name} Train Loss')

plt.title('CNN vs MobileNetV2 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Accuracy Bar Comparison
results_df = pd.DataFrame(results).T

results_df['Test Accuracy'].plot(
    kind='bar',
    figsize=(6,4),
    title='Model Accuracy Comparison'
)

plt.ylabel('Accuracy')
plt.xticks(rotation=0)
plt.show()

# %%
# Save Model
os.makedirs('Models', exist_ok=True)

for name, model in models.items():
    model.save(f'Models/{name}.keras')

# %%
import json

with open("class_indices.json","w") as f:
    json.dump(train_generator.class_indices,f)
